# %% [markdown]
# ## Analysis

# %%
import pandas as pd
from datetime import datetime

# 1. Read the three “post‐LLM” CSVs and concatenate them into a single DataFrame
df_v1 = pd.read_csv("CLEANED_POST-LLM_DATASET_v1__20250603_111851.csv")
df_v2 = pd.read_csv("CLEANED_POST-LLM_DATASET_v2__20250603_093547.csv")
df_v3 = pd.read_csv("CLEANED_POST-LLM_DATASET_v3__20250603_144231.csv")

merged_post_llm = pd.concat([df_v1, df_v2, df_v3], ignore_index=True)

# 2. Generate a timestamp string and write the merged DataFrame with datetime in its filename
now_ts = datetime.now().strftime("%Y%m%d_%H%M%S")
merged_filename = f"CLEANED_POST-LLM_DATASET_v1_v2_v3_{now_ts}.csv"
#merged_post_llm.to_csv(merged_filename, index=False)

# 3. Read the “master” cleaned dataset
cleaned_master = pd.read_csv("CLEANED_DATASET_20250531_004116.csv")

# 4. Find rows that are in cleaned_master but NOT in merged_post_llm (by tweet_id)
missing_by_id = cleaned_master[~cleaned_master["tweet_id"].isin(merged_post_llm["tweet_id"])]

# 5. From those “missing” rows, keep only the requested columns
cols_to_keep = [
    "Author ID",
    "Total Engagement",
    "Date",
    "tweet_id",
    "row_num",
    "Normalized Text",
    "langdetect_is_english"
]
missing_selected = missing_by_id[cols_to_keep]

# 6. Write the result to “merged_bad_and_cleaned_v2.csv”
#missing_selected.to_csv("merged_bad_and_cleaned_v2.csv", index=False)

# (Optional) Display the first few rows to verify
missing_selected
# Out:
#                 Author ID  Total Engagement                       Date  \
# 28467        @mirrrroring                75  2020-01-07 17:50:51+00:00
# 839125       @mirrrroring                 2  2013-09-11 20:07:14+00:00
# 900081     @ZamaZingTimmy                 1  2015-07-23 17:23:10+00:00
# 1182046    @maralkalajian                 0  2014-09-07 10:36:17+00:00
# 1560358     @lcitdynamics                 0  2015-08-27 06:36:32+00:00
# 1599906    @Info3Dprinter                 0  2013-06-26 19:13:41+00:00
# 1795123         @reisanar                 0  2014-09-20 17:51:32+00:00
# 1978061      @Best3dprint                 0  2016-01-17 20:21:37+00:00
# 1978062      @Best3dprint                 0  2016-01-14 05:05:26+00:00
# 1978397      @Best3dprint                 0  2013-12-24 15:42:28+00:00
# 1978407      @Best3dprint                 0  2015-09-04 06:26:31+00:00
# 1978756      @Best3dprint                 0  2014-06-06 22:54:29+00:00
# 1980726       @uettribune                 0  2018-10-28 16:45:02+00:00
# 1980727       @bill2earth                 0  2018-08-28 17:40:28+00:00
# 1980728     @_Collecties_                 0  2016-05-14 18:31:08+00:00
# 1980729      @UNBELFUTURO                 0  2020-03-18 21:38:50+00:00
# 1980730    @shaffaafahmed                 0  2017-01-05 03:09:03+00:00
# 1980731     @SteveHustinx                 0  2016-01-04 10:14:57+00:00
# 1980732   @extensionsbook                 0  2016-02-03 21:23:36+00:00
# 1980733       @DJG_author                 0  2013-03-03 20:45:59+00:00
# 1980734     @SunWuKong___                 0  2015-01-30 22:03:17+00:00
# 1980735       @vipertoxin                 0  2017-05-31 09:53:05+00:00
# 1980736     @SunWuKong___                 0  2014-11-27 18:03:37+00:00
# 1980737       @Markforged                 0  2020-05-20 20:45:02+00:00
# 1980738    @shaffaafahmed                 0  2015-05-14 02:52:36+00:00
# 1984669      @Best3dprint                 0  2016-05-11 12:13:31+00:00
# 1984888      @Best3dprint                 0  2015-04-30 08:10:11+00:00
# 1984978      @Best3dprint                 0  2015-10-05 16:56:28+00:00
# 1985253      @Best3dprint                 0  2016-04-19 17:22:53+00:00
# 1985386     @milainyfidel                 0  2014-07-14 12:11:53+00:00
# 1985620  @niiqkiitahgiirl                 0  2014-07-22 15:39:29+00:00
# 1985632  @niiqkiitahgiirl                 0  2016-08-30 11:45:37+00:00
# 1985655      @Best3dprint                 0  2014-07-30 22:27:22+00:00
# 1985656      @Best3dprint                 0  2014-01-30 17:12:51+00:00
#
#                                           tweet_id  row_num  \
# 28467        @mirrrroring_2020-01-07T17:50:51.000Z   524007
# 839125       @mirrrroring_2013-09-11T20:07:14.000Z  5959718
# 900081     @ZamaZingTimmy_2015-07-23T17:23:10.000Z  4619863
# 1182046    @maralkalajian_2014-09-07T10:36:17.000Z  4777125
# 1560358     @lcitdynamics_2015-08-27T06:36:32.000Z  4570458
# 1599906    @Info3Dprinter_2013-06-26T19:13:41.000Z  6060161
# 1795123         @reisanar_2014-09-20T17:51:32.000Z  5251081
# 1978061      @Best3dprint_2016-01-17T20:21:37.000Z  1545085
# 1978062      @Best3dprint_2016-01-14T05:05:26.000Z  2099809
# 1978397      @Best3dprint_2013-12-24T15:42:28.000Z  5913471
# 1978407      @Best3dprint_2015-09-04T06:26:31.000Z  3778810
# 1978756      @Best3dprint_2014-06-06T22:54:29.000Z  4793480
# 1980726       @uettribune_2018-10-28T16:45:02.000Z  3248587
# 1980727       @bill2earth_2018-08-28T17:40:28.000Z  3312583
# 1980728     @_Collecties__2016-05-14T18:31:08.000Z   673958
# 1980729      @UNBELFUTURO_2020-03-18T21:38:50.000Z   285629
# 1980730    @shaffaafahmed_2017-01-05T03:09:03.000Z  1315999
# 1980731     @SteveHustinx_2016-01-04T10:14:57.000Z  1104071
# 1980732   @extensionsbook_2016-02-03T21:23:36.000Z  2134929
# 1980733       @DJG_author_2013-03-03T20:45:59.000Z  6003645
# 1980734     @SunWuKong____2015-01-30T22:03:17.000Z  3722532
# 1980735       @vipertoxin_2017-05-31T09:53:05.000Z  2034515
# 1980736     @SunWuKong____2014-11-27T18:03:37.000Z  5441821
# 1980737       @Markforged_2020-05-20T20:45:02.000Z   461188
# 1980738    @shaffaafahmed_2015-05-14T02:52:36.000Z  4086191
# 1984669      @Best3dprint_2016-05-11T12:13:31.000Z  1755596
# 1984888      @Best3dprint_2015-04-30T08:10:11.000Z  3862549
# 1984978      @Best3dprint_2015-10-05T16:56:28.000Z  4454881
# 1985253      @Best3dprint_2016-04-19T17:22:53.000Z  1237960
# 1985386     @milainyfidel_2014-07-14T12:11:53.000Z  5207438
# 1985620  @niiqkiitahgiirl_2014-07-22T15:39:29.000Z  4968642
# 1985632  @niiqkiitahgiirl_2016-08-30T11:45:37.000Z  1080545
# 1985655      @Best3dprint_2014-07-30T22:27:22.000Z  5422107
# 1985656      @Best3dprint_2014-01-30T17:12:51.000Z  4972803
#
#                                            Normalized Text  \
# 28467    i’ve decided to start giving away works that m...
# 839125   wanted: 3d printing nerd who can make me finge...
# 900081   great job lani! you crushed it, just as you ar...
# 1182046  mt @eric_gervet : the magic of 3d printing :) ...
# 1560358  shut up and take my money already! its amazing...
# 1599906  re: " 3d printing is a gimmick" - uog, 3d prin...
# 1795123  3d printing is freaking awesome #makerfaire201...
# 1978061  @abstractunderground | #3dprint | the #bridge ...
# 1978062  @abstractunderground | #3dprint | on that stud...
# 1978397  @akbcustoms | new button for masada buttstock ...
# 1978407  @alessio_bigini | #3dprint | 3d printed cable ...
# 1978756  @3douglasuy | #3dprint | 3douglas's all terrai...
# 1980726  >> campus achievement << hamza naseer khilji, ...
# 1980727  >> breaking: the owner of a texas company that...
# 1980728  >> makerbot replicator mini compact 3d printer...
# 1980729  >> medical company threatens to sue volunteers...
# 1980730  >> the da vinci nano is a plug-and-play 3d pri...
# 1980731  >> the creatr hs is a desktop #3d printer that...
# 1980732  >> stratasys and adobe team up to make 3d prin...
# 1980733  >> rt a.r.karthick @arkarthick will 3d printin...
# 1980734  >> redditor wants custom 3d printed phone case...
# 1980735  >> presstv-new zealand launches into space wit...
# 1980736  >> op asks for a 3d printed penis of her decea...
# 1980737  >> new webinar on-demand << "reducing cost, em...
# 1980738  >> new coloring technique creates perfect spot...
# 1984669  @valvox81 | #3dprint | 3d printer at work. #in...
# 1984888  @waywardson99 | #3dprint | this is one of the ...
# 1984978  @tommstark | #3dprint | #whoisthatpokemon #who...
# 1985253  @treasuretrovedesign | #3dprint | this is grea...
# 1985386  [ #olle_jeffry ] a 15-year-old is developing a...
# 1985620  [ #pokel_here ] andrea morgante abstracts pero...
# 1985632  [ #pokel_here ] dus architects builds 3d-print...
# 1985655  @zeke_frazier | #3dprint | i freaking want one...
# 1985656  @zazzyjewelry | he could probably do with a li...
#
#          langdetect_is_english
# 28467                     True
# 839125                    True
# 900081                    True
# 1182046                   True
# 1560358                   True
# 1599906                   True
# 1795123                   True
# 1978061                   True
# 1978062                   True
# 1978397                   True
# 1978407                   True
# 1978756                   True
# 1980726                   True
# 1980727                   True
# 1980728                   True
# 1980729                   True
# 1980730                   True
# 1980731                   True
# 1980732                   True
# 1980733                   True
# 1980734                   True
# 1980735                   True
# 1980736                   True
# 1980737                   True
# 1980738                   True
# 1984669                   True
# 1984888                   True
# 1984978                   True
# 1985253                   True
# 1985386                   True
# 1985620                   True
# 1985632                   True
# 1985655                   True
# 1985656                   True

# %%
len(missing_selected)
# Out:
# 34

# %%
len(merged_post_llm)
# Out:
# 2836611

# %%
len(cleaned_master)
# Out:
# 2835759

# %% [markdown]
# ## Duplicate Check Before Mergin

# %%
# 1. Identify duplicates in merged_post_llm based on tweet_id and row_num
dupes_merged = merged_post_llm[
    merged_post_llm.duplicated(subset=["tweet_id", "row_num"], keep=False)
]
print(f"Duplicates in merged_post_llm ({len(dupes_merged)} rows):")
print(dupes_merged)

# 2. Identify duplicates in cleaned_master based on tweet_id and row_num
dupes_cleaned = cleaned_master[
    cleaned_master.duplicated(subset=["tweet_id", "row_num"], keep=False)
]
print(f"\nDuplicates in cleaned_master ({len(dupes_cleaned)} rows):")
print(dupes_cleaned)
# Out:
# Duplicates in merged_post_llm (1224 rows):
#                                           tweet_id    row_num  category  \
# 600               @tollsy_2014-03-29T16:51:04.000Z  4667710.0  Use-case
# 8385          @ACSPhysics_2023-11-22T14:13:11.000Z  6405482.0  Use-case
# 8404     @mllevanessadias_2016-10-06T16:30:00.000Z  1422754.0  Use-case
# 8418              @KB1REQ_2013-11-07T02:09:29.000Z  5740290.0  Use-case
# 46192        @Machenideas_2019-12-04T14:47:44.000Z  2625885.0  Use-case
# ...                                            ...        ...       ...
# 2824653  @Cosmeti08841509_2019-02-27T13:21:54.000Z  2364816.0  Use-case
# 2824654        @ElliotOJH_2023-07-26T15:37:14.000Z  6359771.0  Use-case
# 2824656    @derbycollege_2012-08-06 13:18:30+00:00   114668.0  Use-case
# 2824756       @mirrroring_2020-01-07T17:50:51.000Z   524007.0  Use-case
# 2825251       @mirrroring_2013-09-11T20:07:14.000Z  5959718.0       NaN
#
#                    subcategory sentiment tweet_language
# 600                   Use-case   Neutral        English
# 8385                  Use-case  Positive        English
# 8404                  Use-case  Positive        English
# 8418                  Use-case   Neutral        English
# 46192                 Use-case   Neutral        English
# ...                        ...       ...            ...
# 2824653       Medical / Dental   Neutral        English
# 2824654       Medical / Dental  Positive        English
# 2824656  Academic Institutions  Positive        English
# 2824756          Architectural   Neutral        English
# 2825251                    NaN   Neutral        English
#
# [1224 rows x 6 columns]
#
# Duplicates in cleaned_master (0 rows):
# Empty DataFrame
# Columns: [Author ID, Total Engagement, Date, tweet_id, row_num, Normalized Text, langdetect_is_english]
# Index: []

# %%
dupes_merged
# Out:
#                                           tweet_id    row_num  category  \
# 600               @tollsy_2014-03-29T16:51:04.000Z  4667710.0  Use-case
# 8385          @ACSPhysics_2023-11-22T14:13:11.000Z  6405482.0  Use-case
# 8404     @mllevanessadias_2016-10-06T16:30:00.000Z  1422754.0  Use-case
# 8418              @KB1REQ_2013-11-07T02:09:29.000Z  5740290.0  Use-case
# 46192        @Machenideas_2019-12-04T14:47:44.000Z  2625885.0  Use-case
# ...                                            ...        ...       ...
# 2824653  @Cosmeti08841509_2019-02-27T13:21:54.000Z  2364816.0  Use-case
# 2824654        @ElliotOJH_2023-07-26T15:37:14.000Z  6359771.0  Use-case
# 2824656    @derbycollege_2012-08-06 13:18:30+00:00   114668.0  Use-case
# 2824756       @mirrroring_2020-01-07T17:50:51.000Z   524007.0  Use-case
# 2825251       @mirrroring_2013-09-11T20:07:14.000Z  5959718.0       NaN
#
#                    subcategory sentiment tweet_language
# 600                   Use-case   Neutral        English
# 8385                  Use-case  Positive        English
# 8404                  Use-case  Positive        English
# 8418                  Use-case   Neutral        English
# 46192                 Use-case   Neutral        English
# ...                        ...       ...            ...
# 2824653       Medical / Dental   Neutral        English
# 2824654       Medical / Dental  Positive        English
# 2824656  Academic Institutions  Positive        English
# 2824756          Architectural   Neutral        English
# 2825251                    NaN   Neutral        English
#
# [1224 rows x 6 columns]

# %%
# From the previously identified duplicates (dupes_merged), filter for groups
# where the “category” column has more than one unique value.

dupes_diff_category = (
    dupes_merged
      .groupby(["tweet_id", "row_num"])
      .filter(lambda grp: grp["category"].nunique() > 1)
      .sort_values(["tweet_id", "row_num"])
)

print(f"{len(dupes_diff_category)} rows where duplicates have differing categories:")
dupes_diff_category
# Out:
# 82 rows where duplicates have differing categories:
#                                          tweet_id    row_num  \
# 1984971  @3DPelectronics_2016-01-08T12:10:33.000Z  1259002.0
# 2821344  @3DPelectronics_2016-01-08T12:10:33.000Z  1259002.0
# 1609296     @3DPrintGirl_2018-05-09T21:08:36.000Z  3574464.0
# 2813859     @3DPrintGirl_2018-05-09T21:08:36.000Z  3574464.0
# 2691208          @3Dable_2019-02-26T10:43:11.000Z  2617485.0
# ...                                           ...        ...
# 2813557    @tradelawnews_2020-01-24T02:55:08.000Z   429531.0
# 356420     @trendonwords_2018-08-28T23:20:17.000Z  3303927.0
# 2816331    @trendonwords_2018-08-28T23:20:17.000Z  3303927.0
# 356384         @zonamya1_2018-07-12T05:19:10.000Z  3238439.0
# 2816325        @zonamya1_2018-07-12T05:19:10.000Z  3238439.0
#
#                   category                        subcategory sentiment  \
# 1984971           Use-case                           Use-case   Neutral
# 2821344      Technological                          Materials  Positive
# 1609296           Use-case                           Use-case  Positive
# 2813859      Technological  Software, Firmware & Design Tools   Neutral
# 2691208           Use-case                           Use-case   Neutral
# ...                    ...                                ...       ...
# 2813557  Business-relevant    Intellectual Property & Patents   Neutral
# 356420            Use-case                           Use-case  Negative
# 2816331  Business-relevant                              Other  Negative
# 356384            Use-case                           Use-case   Neutral
# 2816325  Business-relevant                              Other   Neutral
#
#         tweet_language
# 1984971        English
# 2821344        English
# 1609296        English
# 2813859        English
# 2691208        English
# ...                ...
# 2813557        English
# 356420         English
# 2816331        English
# 356384         English
# 2816325        English
#
# [82 rows x 6 columns]

# %%
# 1. Recompute dupes_merged from the updated merged_post_llm
dupes_merged = merged_post_llm[
    merged_post_llm.duplicated(subset=["tweet_id", "row_num"], keep=False)
]

# 2. Identify (tweet_id, row_num) pairs where duplicates have differing categories
keys_diff = (
    dupes_merged
      .groupby(["tweet_id", "row_num"])
      .filter(lambda grp: grp["category"].nunique() > 1)
      .loc[:, ["tweet_id", "row_num"]]
      .drop_duplicates()
)

# 3. Build a MultiIndex of those keys
idx_diff = pd.MultiIndex.from_frame(keys_diff)

# 4. Create a mask on merged_post_llm for rows matching any of those keys
mask = merged_post_llm.set_index(["tweet_id", "row_num"]).index.isin(idx_diff)

# 5. Set both category and subcategory to "N/A" for all masked rows
merged_post_llm.loc[mask, ["category", "subcategory"]] = "N/A"

# 6. (Verify) Recompute duplicates with differing categories
dupes_merged = merged_post_llm[
    merged_post_llm.duplicated(subset=["tweet_id", "row_num"], keep=False)
]
dupes_diff_category = (
    dupes_merged
      .groupby(["tweet_id", "row_num"])
      .filter(lambda grp: grp["category"].nunique() > 1)
)
print(f"{len(dupes_diff_category)} rows still have differing categories:")
dupes_diff_category
# Out:
# 0 rows still have differing categories:
# Empty DataFrame
# Columns: [tweet_id, row_num, category, subcategory, sentiment, tweet_language]
# Index: []

# %%
# From the previously identified duplicates (dupes_merged), filter for groups
# where the “category” column has more than one unique value.

dupes_diff_category = (
    dupes_merged
      .groupby(["tweet_id", "row_num"])
      .filter(lambda grp: grp["category"].nunique() > 1)
      .sort_values(["tweet_id", "row_num"])
)

print(f"{len(dupes_diff_category)} rows where duplicates have differing categories:")
dupes_diff_category
# Out:
# 0 rows where duplicates have differing categories:
# Empty DataFrame
# Columns: [tweet_id, row_num, category, subcategory, sentiment, tweet_language]
# Index: []

# %%
# 1. Identify duplicates in merged_post_llm based on tweet_id and row_num
dupes_merged = merged_post_llm[
    merged_post_llm.duplicated(subset=["tweet_id", "row_num"], keep=False)
]
print(f"Duplicates in merged_post_llm ({len(dupes_merged)} rows):")
print(dupes_merged)

# 2. Identify duplicates in cleaned_master based on tweet_id and row_num
dupes_cleaned = cleaned_master[
    cleaned_master.duplicated(subset=["tweet_id", "row_num"], keep=False)
]
print(f"\nDuplicates in cleaned_master ({len(dupes_cleaned)} rows):")
print(dupes_cleaned)
# Out:
# Duplicates in merged_post_llm (1224 rows):
#                                           tweet_id    row_num  category  \
# 600               @tollsy_2014-03-29T16:51:04.000Z  4667710.0  Use-case
# 8385          @ACSPhysics_2023-11-22T14:13:11.000Z  6405482.0  Use-case
# 8404     @mllevanessadias_2016-10-06T16:30:00.000Z  1422754.0  Use-case
# 8418              @KB1REQ_2013-11-07T02:09:29.000Z  5740290.0  Use-case
# 46192        @Machenideas_2019-12-04T14:47:44.000Z  2625885.0  Use-case
# ...                                            ...        ...       ...
# 2824653  @Cosmeti08841509_2019-02-27T13:21:54.000Z  2364816.0  Use-case
# 2824654        @ElliotOJH_2023-07-26T15:37:14.000Z  6359771.0  Use-case
# 2824656    @derbycollege_2012-08-06 13:18:30+00:00   114668.0  Use-case
# 2824756       @mirrroring_2020-01-07T17:50:51.000Z   524007.0  Use-case
# 2825251       @mirrroring_2013-09-11T20:07:14.000Z  5959718.0       NaN
#
#                    subcategory sentiment tweet_language
# 600                   Use-case   Neutral        English
# 8385                  Use-case  Positive        English
# 8404                  Use-case  Positive        English
# 8418                  Use-case   Neutral        English
# 46192                 Use-case   Neutral        English
# ...                        ...       ...            ...
# 2824653       Medical / Dental   Neutral        English
# 2824654       Medical / Dental  Positive        English
# 2824656  Academic Institutions  Positive        English
# 2824756          Architectural   Neutral        English
# 2825251                    NaN   Neutral        English
#
# [1224 rows x 6 columns]
#
# Duplicates in cleaned_master (0 rows):
# Empty DataFrame
# Columns: [Author ID, Total Engagement, Date, tweet_id, row_num, Normalized Text, langdetect_is_english]
# Index: []

# %% [markdown]
# ### Drop Duplicates

# %%
# Drop all duplicate rows in merged_post_llm based on tweet_id and row_num
merged_post_llm = merged_post_llm.drop_duplicates(
    subset=["tweet_id", "row_num"],
    keep="first"
).reset_index(drop=True)

# %% [markdown]
# ## Merge Inference Output Dataset with Cleaned Master Dataset

# %%
# Merge merged_post_llm with cleaned_master on both tweet_id and row_num,
# bringing in Date, Normalized Text, and Total Engagement
now_ts = datetime.now().strftime("%Y%m%d_%H%M%S")
merged_final = merged_post_llm.merge(
    cleaned_master[["tweet_id", "row_num", "Date", "Normalized Text", "Total Engagement"]],
    on=["tweet_id", "row_num"],
    how="inner"
)


# (Optional) Write out the merged result
#merged_final.to_csv(f"CLEANED_POST-LLM_MERGED_WITH_MASTER_{now_ts}.csv", index=False)
merged_final
# Out:
#                                         tweet_id    row_num  \
# 0                @3HTi__2017-04-13T21:13:00.000Z  1938218.0
# 1             @benzuria_2017-06-12T16:33:14.000Z  1614375.0
# 2          @stephcurcio_2016-02-22T16:27:33.000Z   904891.0
# 3           @patesalo_e_2017-06-10T10:26:13.000Z   697479.0
# 4              @eTeknix_2015-04-19T18:04:07.000Z  4456221.0
# ...                                          ...        ...
# 2835719        @technws_2016-08-22T19:24:23.000Z  1110601.0
# 2835720  @supermineadam_2014-10-04T06:40:11.000Z  5527728.0
# 2835721       @MadeGrid_2013-07-16T11:24:16.000Z  5978567.0
# 2835722      @lilli_eye_2017-02-07T12:33:08.000Z  1698758.0
# 2835723    @ross_kramer_2015-10-21T12:45:03.000Z  4526287.0
#
#                   category                      subcategory sentiment  \
# 0        Business-relevant  Intellectual Property & Patents   Neutral
# 1        Business-relevant  Intellectual Property & Patents   Neutral
# 2        Business-relevant  Intellectual Property & Patents  Positive
# 3        Business-relevant  Intellectual Property & Patents   Neutral
# 4                 Use-case  Consumer Products / Electronics  Positive
# ...                    ...                              ...       ...
# 2835719           Use-case  Consumer Products / Electronics   Neutral
# 2835720      Technological    Hardware, Sensors & Equipment  Positive
# 2835721           Use-case  Consumer Products / Electronics   Neutral
# 2835722  Business-relevant                            Other   Neutral
# 2835723           Use-case  Consumer Products / Electronics   Neutral
#
#         tweet_language                       Date  \
# 0              English  2017-04-13 21:13:00+00:00
# 1              English  2017-06-12 16:33:14+00:00
# 2              English  2016-02-22 16:27:33+00:00
# 3              English  2017-06-10 10:26:13+00:00
# 4              English  2015-04-19 18:04:07+00:00
# ...                ...                        ...
# 2835719        English  2016-08-22 19:24:23+00:00
# 2835720        English  2014-10-04 06:40:11+00:00
# 2835721        English  2013-07-16 11:24:16+00:00
# 2835722        English  2017-02-07 12:33:08+00:00
# 2835723        English  2015-10-21 12:45:03+00:00
#
#                                            Normalized Text  Total Engagement
# 0        disney files patent for a 3d printed soft robo...                 0
# 1        disney files patent for 'anti-scanning' materi...                 0
# 2        disney files patent application for high resol...                 0
# 3        disney files patent application for "anti-scan...                 0
# 4        disney fabric 3d printer – creations you’ll wa...                 0
# ...                                                    ...               ...
# 2835719  crunchgear: roll your own business cards with ...                 0
# 2835720  cubepro 3d printer : 3d printing . real. pro. ...                 0
# 2835721  create your own products with ebay exact. (inc...                 0
# 2835722  daniela bertol at mad: shapeways designer in r...                 0
# 2835723  custom fitted 3d printed retail experience in ...                 0
#
# [2835724 rows x 9 columns]

# %%
len(cleaned_master) - len(merged_final)
# Out:
# 35

# %%
# Identify duplicate rows in merged_final based on tweet_id and row_num
dupes = merged_final[
    merged_final.duplicated(subset=["tweet_id", "row_num"], keep=False)
].sort_values(["tweet_id", "row_num"])

# Display how many duplicates and show the first few
print(f"{len(dupes)} duplicate rows found in merged_final")
dupes.head()
# Out:
# 0 duplicate rows found in merged_final
# Empty DataFrame
# Columns: [tweet_id, row_num, category, subcategory, sentiment, tweet_language, Date, Normalized Text, Total Engagement]
# Index: []
