# %% [markdown]
# ## Analysis

# %%
# import pandas as pd

# # 1. Read the three “bad” CSVs into individual DataFrames
# bad_business = pd.read_csv("bad_business_relevant_2025-06-03_070636.csv")
# bad_technological = pd.read_csv("bad_technological_2025-06-03_070711.csv")

# bad_use_case = pd.read_csv("bad_use_case_2025-06-03_070714.csv")

# # 2. Concatenate them into a single DataFrame
# bad_all = pd.concat([bad_business, bad_technological, bad_use_case], ignore_index=True)

# # 3. Read the cleaned dataset
# cleaned = pd.read_csv("CLEANED_DATASET_20250531_004116.csv")

# # 4. Merge: keep only rows in `cleaned` whose tweet_id also appears in any of the “bad” DataFrames
# #    We select only the tweet_id column from bad_all, then do an inner merge on tweet_id.
# merged = cleaned.merge(
#     bad_all[["tweet_id"]].drop_duplicates(), 
#     on="tweet_id", 
#     how="inner"
# )

# # 5. Display the resulting DataFrame (in Jupyter, this will show a table)
# merged

# # 6. Write the merged DataFrame to a new CSV
# merged.to_csv("merged_bad_and_cleaned.csv", index=False)

# %%
merged
# Out:
#               Author ID  Total Engagement                       Date  \
# 0           @rveenewman            213595  2019-01-09 13:25:07+00:00
# 1         @ThomasDangAB               280  2020-04-13 21:00:41+00:00
# 2                 @nano               204  2021-10-10 17:00:11+00:00
# 3        @EOS3DPrinting               157  2017-10-18 14:58:19+00:00
# 4          @DrOlubamiji               157  2021-02-02 20:30:51+00:00
# ...                 ...               ...                        ...
# 11861      @ProHacktivo                 0  2021-07-09 17:51:32+00:00
# 11862      @DRSCornwall                 0  2020-06-21 22:45:12+00:00
# 11863  @TurboKitsdotcom                 0  2020-04-13 16:10:05+00:00
# 11864         @_Brandor                 0  2016-08-05 01:04:46+00:00
# 11865         @Chatsoff                 0  2017-08-16 13:59:09+00:00
#
#                                         tweet_id  row_num  \
# 0           @rveenewman_2019-01-09T13:25:07.000Z  2447524
# ...
